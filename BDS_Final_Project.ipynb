# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


train_data=pd.read_csv('train.csv')
test_data=pd.read_csv('test.csv')
original = pd.read_csv('original.csv')

# %%
original['Attrition'] = (original['Attrition'] == 'Yes').astype(np.int64)
original
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# Verified length of the data

# %%
train_data.shape
# Out:
# (1677, 35)

# %%
test_data.shape
# Out:
# (1119, 34)

# %% [markdown]
# View the data using head function which returns top rows

# %%
train_data.head()
# Out:
#    id  Age     BusinessTravel  DailyRate              Department  \
# 0   0   36  Travel_Frequently        599  Research & Development
# 1   1   35      Travel_Rarely        921                   Sales
# 2   2   32      Travel_Rarely        718                   Sales
# 3   3   38      Travel_Rarely       1488  Research & Development
# 4   4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 0                        4  ...            80                 1
# 1                        1  ...            80                 1
# ...

# %%
test_data.head()
# Out:
#      id  Age     BusinessTravel  DailyRate              Department  \
# 0  1677   19         Non-Travel        992  Research & Development
# 1  1678   45      Travel_Rarely       1136                   Sales
# 2  1679   37      Travel_Rarely        155  Research & Development
# 3  1680   32      Travel_Rarely        688  Research & Development
# 4  1681   29  Travel_Frequently        464  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          1        Medical              1
# 1                 4          4      Marketing              1
# 2                13          3  Life Sciences              1
# 3                 1          4  Life Sciences              1
# 4                 9          1  Life Sciences              1
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# 0                        4  ...                        4             80
# ...

# %%
train_data.columns
# Out:
# Index(['id', 'Age', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %%
test_data.columns
# Out:
# Index(['id', 'Age', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1677 entries, 0 to 1676
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1677 non-null   int64
#  1   Age                       1677 non-null   int64
#  2   BusinessTravel            1677 non-null   object
#  3   DailyRate                 1677 non-null   int64
#  4   Department                1677 non-null   object
#  5   DistanceFromHome          1677 non-null   int64
#  6   Education                 1677 non-null   int64
#  7   EducationField            1677 non-null   object
#  8   EmployeeCount             1677 non-null   int64
#  9   EnvironmentSatisfaction   1677 non-null   int64
#  10  Gender                    1677 non-null   object
#  11  HourlyRate                1677 non-null   int64
#  12  JobInvolvement            1677 non-null   int64
#  13  JobLevel                  1677 non-null   int64
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119 entries, 0 to 1118
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1119 non-null   int64
#  1   Age                       1119 non-null   int64
#  2   BusinessTravel            1119 non-null   object
#  3   DailyRate                 1119 non-null   int64
#  4   Department                1119 non-null   object
#  5   DistanceFromHome          1119 non-null   int64
#  6   Education                 1119 non-null   int64
#  7   EducationField            1119 non-null   object
#  8   EmployeeCount             1119 non-null   int64
#  9   EnvironmentSatisfaction   1119 non-null   int64
#  10  Gender                    1119 non-null   object
#  11  HourlyRate                1119 non-null   int64
#  12  JobInvolvement            1119 non-null   int64
#  13  JobLevel                  1119 non-null   int64
# ...

# %%
train_data.describe()
# Out:
#                 id          Age    DailyRate  DistanceFromHome    Education  \
# count  1677.000000  1677.000000  1677.000000       1677.000000  1677.000000
# mean    838.000000    36.036971   892.749553          8.683959     2.937984
# std     484.252517     8.507112   374.496259          7.826143     1.039078
# min       0.000000    18.000000   107.000000          1.000000     1.000000
# 25%     419.000000    30.000000   589.000000          2.000000     2.000000
# 50%     838.000000    35.000000   890.000000          7.000000     3.000000
# 75%    1257.000000    41.000000  1223.000000         12.000000     4.000000
# max    1676.000000    60.000000  3921.000000         29.000000    15.000000
#
#        EmployeeCount  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count         1677.0              1677.000000  1677.000000     1677.000000
# mean             1.0                 2.757901    67.798450        2.782349
# ...

# %%
test_data.describe()
# Out:
#                 id          Age    DailyRate  DistanceFromHome    Education  \
# count  1119.000000  1119.000000  1119.000000       1119.000000  1119.000000
# mean   2236.000000    36.147453   883.550492          8.667560     2.941912
# std     323.171781     8.786102   366.427230          7.772384     1.012986
# min    1677.000000    18.000000     6.000000          1.000000     1.000000
# 25%    1956.500000    30.000000   589.000000          2.000000     2.000000
# 50%    2236.000000    35.000000   889.000000          7.000000     3.000000
# 75%    2515.500000    41.000000  1206.000000         12.000000     4.000000
# max    2795.000000    59.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count         1119.0              1119.000000  1119.000000     1119.000000
# mean             1.0                 2.736372    68.226095        2.741734
# ...

# %%
sns.countplot(x='Attrition',data=train_data)
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
train_data.isna().sum()
# Out:
# id                          0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
test_data.isna().sum()
# Out:
# id                          0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
# Check for missing values
train_data.isnull().sum()
# Out:
# id                          0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
# Check for missing values
test_data.isnull().sum()
# Out:
# id                          0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# ...

# %%
sns.heatmap(train_data.isna())
# Out:
# <Axes: >

# %%
sns.heatmap(test_data.isna())
# Out:
# <Axes: >

# %%
test_data.nunique().sort_values()
# Out:
# Over18                         1
# StandardHours                  1
# EmployeeCount                  1
# PerformanceRating              2
# OverTime                       2
# Gender                         2
# MaritalStatus                  3
# BusinessTravel                 3
# Department                     3
# JobSatisfaction                4
# RelationshipSatisfaction       4
# WorkLifeBalance                4
# Education                      5
# StockOptionLevel               5
# JobInvolvement                 5
# EnvironmentSatisfaction        5
# JobLevel                       5
# EducationField                 6
# TrainingTimesLastYear          7
# JobRole                        9
# NumCompaniesWorked            11
# PercentSalaryHike             15
# YearsSinceLastPromotion       16
# YearsInCurrentRole            18
# YearsWithCurrManager          18
# DistanceFromHome              29
# YearsAtCompany                33
# TotalWorkingYears             38
# ...

# %%
feats_to_drop = [col for col in test_data.columns if test_data[col].nunique()==1]
cat_features = [col for col in test_data.columns if test_data[col].nunique() <= 20 and test_data[col].nunique() > 1]
test_data.drop(columns=feats_to_drop, inplace=True)
train_data.drop(columns=feats_to_drop, inplace=True)

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()

ord_enc.fit(test_data[cat_features])

test_data[cat_features] = ord_enc.transform(test_data[cat_features])
test_data.head()
# Out:
#      id  Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0  1677   19             0.0        992         1.0                 1
# 1  1678   45             2.0       1136         2.0                 4
# 2  1679   37             2.0        155         1.0                13
# 3  1680   32             2.0        688         1.0                 1
# 4  1681   29             1.0        464         1.0                 9
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0        0.0             3.0                      4.0     1.0  ...
# 1        3.0             2.0                      3.0     1.0  ...
# 2        2.0             1.0                      4.0     1.0  ...
# 3        3.0             1.0                      3.0     1.0  ...
# 4        0.0             1.0                      3.0     1.0  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                0.0                       3.0               0.0
# ...

# %%
ord_enc = OrdinalEncoder()

ord_enc.fit(train_data[cat_features])

train_data[cat_features] = ord_enc.transform(train_data[cat_features])
train_data.head()
# Out:
#    id  Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   0   36             1.0        599         1.0                24
# 1   1   35             2.0        921         2.0                 8
# 2   2   32             2.0        718         2.0                26
# 3   3   38             2.0       1488         1.0                 2
# 4   4   50             2.0       1017         1.0                 5
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  ...  \
# 0        2.0             3.0                      3.0     1.0  ...
# 1        2.0             4.0                      0.0     1.0  ...
# 2        2.0             2.0                      2.0     1.0  ...
# 3        2.0             3.0                      2.0     0.0  ...
# 4        3.0             3.0                      1.0     0.0  ...
#
#    RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# 0                       1.0               1.0                 10
# ...

# %% [markdown]
# One hot encoding non-numeric feature columns

# %%
# Identifying categorical columns (non-numeric)
categorical_cols = train_data.select_dtypes(include=['object']).columns

# Performing one-hot encoding on these columns
data_encoded = pd.get_dummies(train_data, columns=categorical_cols)

# Displaying the first few rows of the transformed dataset
data_encoded.head()
# Out:
#    id  Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0   0   36        599                24          3              1
# 1   1   35        921                 8          3              1
# 2   2   32        718                26          3              1
# 3   3   38       1488                 2          3              1
# 4   4   50       1017                 5          4              1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  ...  \
# 0                        4          42               3         1  ...
# 1                        1          46               3         1  ...
# 2                        3          80               3         2  ...
# 3                        3          40               3         2  ...
# 4                        2          37               3         5  ...
#
#    JobRole_Research Director  JobRole_Research Scientist  \
# 0                          0                           0
# ...

# %%
# Identifying categorical columns (non-numeric)
categorical_cols = test_data.select_dtypes(include=['object']).columns

# Performing one-hot encoding on these columns
test_data_encoded = pd.get_dummies(test_data, columns=categorical_cols)

# Displaying the first few rows of the transformed dataset
test_data_encoded.head()
# Out:
#      id  Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0  1677   19        992                 1          1              1
# 1  1678   45       1136                 4          4              1
# 2  1679   37        155                13          3              1
# 3  1680   32        688                 1          4              1
# 4  1681   29        464                 9          1              1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  ...  \
# 0                        4          43               3         1  ...
# 1                        3          67               3         2  ...
# 2                        4          41               3         1  ...
# 3                        3          89               2         2  ...
# 4                        3          79               3         1  ...
#
#    JobRole_Research Director  JobRole_Research Scientist  \
# 0                          0                           0
# ...

# %%
# Initialize a list to store the results for each column
results = []

# Loop through all columns
for column in data_encoded.columns:
    if (data_encoded[column].isin([0]).all()) or (data_encoded[column].isin([1]).all()) or (data_encoded[column].isin([80]).all()):
        results.append(f"{column} contains all 0s or all 1s.")

results
# Out:
# ['EmployeeCount contains all 0s or all 1s.',
#  'StandardHours contains all 0s or all 1s.',
#  'Over18_Y contains all 0s or all 1s.']

# %%
# Initialize a list to store the results for each column
results = []

# Loop through all columns
for column in test_data_encoded.columns:
    if (test_data_encoded[column].isin([0]).all()) or (test_data_encoded[column].isin([1]).all()) or (test_data_encoded[column].isin([80]).all()):
        results.append(f"{column} contains all 0s or all 1s.")

results
# Out:
# ['EmployeeCount contains all 0s or all 1s.',
#  'StandardHours contains all 0s or all 1s.',
#  'Over18_Y contains all 0s or all 1s.']

# %%
# Assuming 'df' is your DataFrame
for column in data_encoded.columns:
    value_counts = data_encoded[column].value_counts()
    print(f"Value distribution for {column}:\n{value_counts}\n")


# Assuming 'df' is your DataFrame
numeric_columns = data_encoded.select_dtypes(include=[int, float]).columns
for column in numeric_columns:
    column_stats = data_encoded[column].describe()
    print(f"Summary statistics for {column}:\n{column_stats}\n")


import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame
numeric_columns = data_encoded.select_dtypes(include=[int, float]).columns
for column in numeric_columns:
    plt.figure(figsize=(8, 6))
    sns.histplot(data=data_encoded, x=column, kde=False, element="step")  # Use "step" for a classic bar graph
    plt.title(f"Histogram for {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()
# Out:
# Value distribution for id:
# 0       1
# 1153    1
# 1125    1
# 1124    1
# 1123    1
#        ..
# 556     1
# 555     1
# 554     1
# 553     1
# 1676    1
# Name: id, Length: 1677, dtype: int64
#
# Value distribution for Age:
# 36    101
# 29     96
# 34     95
# 31     90
# 35     89
# 38     88
# 40     79
# 27     67
# 30     66
# 28     62
# 32     60
# 37     58
# 39     54
# 33     50
# 46     47
# 26     45
# 45     41
# 41     40
# 44     39
# 42     36
# 25     36
# 43     29
# 50     29
# 48     28
# 24     23
# 47     22
# 23     20
# 49     19
# 52     18
# 55     17
# 21     16
# 53     15
# 51     14
# 22     14
# 19     13
# 18     12
# 56     10
# 59     10
# 58      9
# 54      7
# 20      6
# 57      4
# 60      3
# Name: Age, dtype: int64
#
# Value distribution for DailyRate:
# 1082    16
# 775     12
# 465     11
# 855     11
# 1329    10
#         ..
# 1452     1
# 1327     1
# 1382     1
# 302      1
# 1141     1
# Name: DailyRate, Length: 625, dtype: int64
# ...

# %%
data_encoded.columns
# Out:
# Index(['id', 'Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EmployeeCount', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition',
#        'BusinessTravel_Non-Travel', 'BusinessTravel_Travel_Frequently',
#        'BusinessTravel_Travel_Rarely', 'Department_Human Resources',
#        'Department_Research & Development', 'Department_Sales',
#        'EducationField_Human Resources', 'EducationField_Life Sciences',
#        'EducationField_Marketing', 'EducationField_Medical',
#        'EducationField_Other', 'EducationField_Technical Degree',
# ...

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

# Making a copy of the train_data to work with it without altering the original dataset
df_copy = data_encoded.copy()

# Dropping the 'Y' column from the copy of the dataset as we don't need it in the features set
df_copy = data_encoded.drop(['Attrition'], axis=1)

# Assigning the remaining columns as features
features = df_copy.loc[:,df_copy.columns]

# Assigning the 'Y' column from the original data as the target variable
target = data_encoded['Attrition']

# Setting up SelectKBest with the ANOVA F-test as the score function to evaluate all features
best_features = SelectKBest(score_func=f_classif, k='all')

# Fitting SelectKBest to the features and target
fit = best_features.fit(features, target)

# Creating a DataFrame with the scores for each feature
featureScores = pd.DataFrame(data=fit.scores_, index=features.columns, columns=['ANOVA Score'])

# Setting up the matplotlib figure with a defined size
plt.subplots(figsize=(5, 20))

# Defining the color map for the heatmap
colors = 'coolwarm' # Assuming 'coolwarm' is intended, which is a valid matplotlib colormap

# Creating the heatmap with the feature scores, sorted by the ANOVA score in descending order
sns.heatmap(featureScores.sort_values(by='ANOVA Score', ascending=False),
            annot=True, cmap=colors, linewidths=0.4, linecolor='black', fmt='.2f')

# Adding a title to the heatmap
plt.title('Selection of Numerical Features')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_selection/_univariate_selection.py:112: UserWarning: Features [ 5 17 52] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_selection/_univariate_selection.py:113: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw

# %%
# data_encoded = data_encoded.drop(['EmployeeCount'], axis=1)
# data_encoded = data_encoded.drop(['StandardHours'], axis=1)
# data_encoded = data_encoded.drop(['Over18_Y'], axis=1)
data_encoded.shape
# Out:
# (1677, 53)

# %%
# test_data_encoded = test_data_encoded.drop(['EmployeeCount'], axis=1)
# test_data_encoded = test_data_encoded.drop(['StandardHours'], axis=1)
# test_data_encoded = test_data_encoded.drop(['Over18_Y'], axis=1)
test_data_encoded = test_data_encoded.drop(['id'], axis=1)
test_data_encoded.shape
# Out:
# (1119, 51)

# %%
train_data['MonthlyIncome/Age'] = train_data['MonthlyIncome'] / train_data['Age']

train_data["Age_risk"] = (train_data["Age"] < 34).astype(int)
train_data["HourlyRate_risk"] = (train_data["HourlyRate"] < 60).astype(int)
train_data["Distance_risk"] = (train_data["DistanceFromHome"] >= 20).astype(int)
train_data["YearsAtCo_risk"] = (train_data["YearsAtCompany"] < 4).astype(int)

train_data['NumCompaniesWorked'] = train_data['NumCompaniesWorked'].replace(0, 1)
train_data['AverageTenure'] = train_data["TotalWorkingYears"] / train_data["NumCompaniesWorked"]
# train_data['YearsAboveAvgTenure'] = train_data['YearsAtCompany'] - train_data['AverageTenure']

train_data['JobHopper'] = ((train_data["NumCompaniesWorked"] > 2) & (train_data["AverageTenure"] < 2.0)).astype(int)

train_data["AttritionRisk"] = train_data["Age_risk"] + train_data["HourlyRate_risk"] + train_data["Distance_risk"] + train_data["YearsAtCo_risk"] + train_data['JobHopper']

# %%
test_data['MonthlyIncome/Age'] = test_data['MonthlyIncome'] / test_data['Age']

test_data["Age_risk"] = (test_data["Age"] < 34).astype(int)
test_data["HourlyRate_risk"] = (test_data["HourlyRate"] < 60).astype(int)
test_data["Distance_risk"] = (test_data["DistanceFromHome"] >= 20).astype(int)
test_data["YearsAtCo_risk"] = (test_data["YearsAtCompany"] < 4).astype(int)

test_data['NumCompaniesWorked'] = test_data['NumCompaniesWorked'].replace(0, 1)
test_data['AverageTenure'] = test_data["TotalWorkingYears"] / test_data["NumCompaniesWorked"]
# test_data['YearsAboveAvgTenure'] = test_data['YearsAtCompany'] - test_data['AverageTenure']

test_data['JobHopper'] = ((test_data["NumCompaniesWorked"] > 2) & (test_data["AverageTenure"] < 2.0)).astype(int)

test_data["AttritionRisk"] = test_data["Age_risk"] + test_data["HourlyRate_risk"] + test_data["Distance_risk"] + test_data["YearsAtCo_risk"] + test_data['JobHopper']

# %%
from sklearn.preprocessing import StandardScaler

# Normalize the features
scaler = StandardScaler()

all_columns = train_data.columns

# Drop the ID column, since it is irrelvant
X=train_data.drop(['id', 'Attrition'], axis=1)
X_normalized = scaler.fit_transform(X)

y=train_data['Attrition']

X.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   36             1.0        599         1.0                24        2.0
# 1   35             2.0        921         2.0                 8        2.0
# 2   32             2.0        718         2.0                26        2.0
# 3   38             2.0       1488         1.0                 2        2.0
# 4   50             2.0       1017         1.0                 5        3.0
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  ...  \
# 0             3.0                      3.0     1.0          42  ...
# 1             4.0                      0.0     1.0          46  ...
# 2             2.0                      2.0     1.0          80  ...
# 3             3.0                      2.0     0.0          40  ...
# 4             3.0                      1.0     0.0          37  ...
#
#    YearsWithCurrManager  MonthlyIncome/Age  Age_risk  HourlyRate_risk  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.20, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, roc_auc_score
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
# !pip install catboost
from catboost import CatBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier


# Initialize models
models = {
    "Logistic Regression": LogisticRegression(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "XGBoosting": XGBClassifier(objective='binary:logistic'),
    "LGBMClassifier": LGBMClassifier(verbose = -1),
    "CatBoost": CatBoostClassifier(verbose=False),
    "Bagging Classifier": BaggingClassifier(random_state=42),
    "Ada Boost Classifier": AdaBoostClassifier(random_state=42),
    "KNeighbor Classifier": KNeighborsClassifier()

}

# Train models and store performance metrics
model_performance = {}

# Iterate over each model, train it, make predictions and calculate performance metrics
for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    y_prob = model.predict_proba(x_test)[:, 1]
    accuracy = accuracy_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_prob)
    model_performance[name] = {"Accuracy": accuracy, "ROC AUC": roc_auc}

# Print out the stored performance metrics for each model
for model, performance in model_performance.items():
    print(f"{model}:")
    for metric, value in performance.items():
        print(f"  {metric}: {value:.8f}")
    print()
# Out:
# ...
# Logistic Regression:
#   Accuracy: 0.89583333
#   ROC AUC: 0.81452366
#
# Random Forest:
#   Accuracy: 0.87797619
#   ROC AUC: 0.81179950
#
# Gradient Boosting:
#   Accuracy: 0.88690476
#   ROC AUC: 0.81646949
#
# XGBoosting:
#   Accuracy: 0.88392857
#   ROC AUC: 0.80136986
#
# LGBMClassifier:
#   Accuracy: 0.87797619
#   ROC AUC: 0.80323786
#
# CatBoost:
#   Accuracy: 0.88095238
#   ROC AUC: 0.82355230
#
# Bagging Classifier:
#   Accuracy: 0.86011905
#   ROC AUC: 0.73509496
#
# Ada Boost Classifier:
#   Accuracy: 0.88690476
#   ROC AUC: 0.82689913
#
# KNeighbor Classifier:
#   Accuracy: 0.86904762
#   ROC AUC: 0.72700031

# %%
test_data_encoded.nunique().sort_values()
# Out:
# EducationField_Human Resources          2
# BusinessTravel_Non-Travel               2
# BusinessTravel_Travel_Frequently        2
# BusinessTravel_Travel_Rarely            2
# Department_Human Resources              2
# Department_Research & Development       2
# Department_Sales                        2
# JobHopper                               2
# EducationField_Life Sciences            2
# EducationField_Marketing                2
# EducationField_Medical                  2
# EducationField_Other                    2
# EducationField_Technical Degree         2
# Gender_Female                           2
# Gender_Male                             2
# JobRole_Healthcare Representative       2
# JobRole_Human Resources                 2
# JobRole_Laboratory Technician           2
# JobRole_Research Director               2
# JobRole_Research Scientist              2
# JobRole_Sales Executive                 2
# JobRole_Sales Representative            2
# ...

# %%
X
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      36             1.0        599         1.0                24        2.0
# 1      35             2.0        921         2.0                 8        2.0
# 2      32             2.0        718         2.0                26        2.0
# 3      38             2.0       1488         1.0                 2        2.0
# 4      50             2.0       1017         1.0                 5        3.0
# ...   ...             ...        ...         ...               ...        ...
# 1672   30             2.0        945         2.0                 1        2.0
# 1673   32             2.0       1303         1.0                 2        2.0
# 1674   29             1.0       1184         0.0                24        2.0
# 1675   36             2.0        441         2.0                 9        1.0
# 1676   36             2.0       1141         1.0                20        2.0
#
# ...

# %%
test_data.columns
# Out:
# Index(['id', 'Age', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'MonthlyIncome/Age',
#        'Age_risk', 'HourlyRate_risk', 'Distance_risk', 'YearsAtCo_risk',
#        'AverageTenure', 'JobHopper', 'AttritionRisk'],
#       dtype='object')

# %%
from catboost import CatBoostClassifier, Pool, cv
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
test_data_copy = test_data.drop(['id'], axis=1)
# Create a CatBoost pool object with the entire dataset
data_pool = Pool(data=X_normalized, label=y)

# Load the test dataset
# test_data = pd.read_csv('test.csv')

# Drop the ID and 39 columns
test_X = scaler.fit_transform(test_data_copy)

# Convert the test dataset into a Pool object
test_pool = Pool(data=test_X)

# CAT
# Define the CatBoost classifier parameters
catboost_params = {'loss_function': 'CrossEntropy',
                     'learning_rate': 0.76,
                     'l2_leaf_reg': 0.014,
                     'colsample_bylevel': 0.06,
                     'depth': 1,
                     'boosting_type': 'Plain',
                     'bootstrap_type': 'Bernoulli',
                     'min_data_in_leaf': 18,
                     'one_hot_max_size': 14,
                     'subsample': 0.99}
cat_model = CatBoostClassifier(**catboost_params)
cat_model.fit(X_normalized, y, verbose=False)
# cat_model.fit(data_pool)
# cat_predictions = cat_model.predict(test_pool, prediction_type='Probability')[:, 1]
cat_predictions = cat_model.predict_proba(test_X)[:, 1]



# XGB
# Define the XGBoost classifier parameters
# random params values - make sure to tune yours
xgb_params = {'n_estimators': 150,
                 'max_depth': 3,
                 'learning_rate': 0.1,
                 'min_child_weight': 4,
                 'subsample': 0.7,
                 'colsample_bytree': 0.3
             }
# Convert the dataset into a DMatrix object
# data_dmatrix = xgb.DMatrix(data=X, label=y)
# cv_results = xgb.cv(dtrain=data_dmatrix, params=xgb_params, nfold=5, num_boost_round=1000, early_stopping_rounds=50, metrics="auc", as_pandas=True)

xgb_model = XGBClassifier(**xgb_params)
xgb_model.fit(X_normalized, y)
xgb_predictions = xgb_model.predict_proba(test_X)[:, 1]

# LightGB
# random params but feel free to tune
lgbm_params = {'n_estimators': 407,
                 'num_rounds': 274,
                 'learning_rate': 0.1,
                 'num_leaves': 195,
                 'max_depth': 9,
                 'min_data_in_leaf': 46,
                 'lambda_l1': 0.01,
                 'lambda_l2': 0.6,
                 'min_gain_to_split': 1.42,
                 'bagging_fraction': 0.45,
                 'feature_fraction': 0.3}
lgb_classifier = LGBMClassifier(**lgbm_params)
lgb_classifier.fit(X_normalized, y)
lgb_predictions = lgb_classifier.predict_proba(test_X)[:, 1]

#
# Give more weight to XGB
final_preds = np.column_stack([xgb_predictions, xgb_predictions,
                              # lgb_predictions,
                               cat_predictions]).mean(axis=1)

# Save predictions to a CSV file or further processing
# print(cat_predictions)
# print("this is dividing line")
# print(xgb_predictions)
# print("this is dividing line")
# print(lgb_predictions)
# final_predict = cat_predictions * 0.425 + xgb_predictions * 0.425 + lgb_predictions * 0.15

output = pd.DataFrame({'id': test_data['id'], 'Attrition': final_preds})
output.to_csv('predictions.csv', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:172: UserWarning: Found `num_rounds` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] min_data_in_leaf is set=46, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=46
# [LightGBM] [Warning] feature_fraction is set=0.3, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3
# [LightGBM] [Warning] lambda_l2 is set=0.6, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.6
# [LightGBM] [Warning] min_gain_to_split is set=1.42, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=1.42
# [LightGBM] [Warning] lambda_l1 is set=0.01, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.01
# [LightGBM] [Warning] num_iterations is set=274, num_rounds=274 will be ignored. Current value: num_iterations=274
# ...

# %%
output.head()
# Out:
#      id  Attrition
# 0  1677   0.151504
# 1  1678   0.102938
# 2  1679   0.018515
# 3  1680   0.083375
# 4  1681   0.459147

# %%
output['Attrition'].plot.hist();

# %%
X.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'MonthlyIncome/Age', 'Age_risk',
#        'HourlyRate_risk', 'Distance_risk', 'YearsAtCo_risk', 'AverageTenure',
#        'JobHopper', 'AttritionRisk'],
#       dtype='object')

# %%
test_data.columns
# Out:
# Index(['id', 'Age', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'MonthlyIncome/Age',
#        'Age_risk', 'HourlyRate_risk', 'Distance_risk', 'YearsAtCo_risk',
#        'AverageTenure', 'JobHopper', 'AttritionRisk'],
#       dtype='object')

# %% [markdown]
# Load data from train and test dataset

# %%
train_data=pd.read_csv('train_dataset.csv')
test_data=pd.read_csv('test_dataset.csv')

# %% [markdown]
# Verified length of the data

# %%
X.shape
# Out:
# (1677, 38)

# %%
test_data.shape
# Out:
# (1119, 39)

# %% [markdown]
# Check both data set columns

# %%
train_data.columns
# Out:
# Index(['Unnamed: 0', 'Index', 'Address', 'FLAG', 'Avg min between sent tnx',
#        'Avg min between received tnx',
#        'Time Diff between first and last (Mins)', 'Sent tnx', 'Received Tnx',
#        'Number of Created Contracts', 'Unique Received From Addresses',
#        'Unique Sent To Addresses', 'min value received', 'max value received ',
#        'avg val received', 'min val sent', 'max val sent', 'avg val sent',
#        'min value sent to contract', 'max val sent to contract',
#        'avg value sent to contract',
#        'total transactions (including tnx to create contract',
#        'total Ether sent', 'total ether received',
#        'total ether sent contracts', 'total ether balance',
#        ' Total ERC20 tnxs', ' ERC20 total Ether received',
#        ' ERC20 total ether sent', ' ERC20 total Ether sent contract',
#        ' ERC20 uniq sent addr', ' ERC20 uniq rec addr',
#        ' ERC20 uniq sent addr.1', ' ERC20 uniq rec contract addr',
# ...

# %%
test_data.columns
# Out:
# Index(['Unnamed: 0', 'Index', 'Address', 'Avg min between sent tnx',
#        'Avg min between received tnx',
#        'Time Diff between first and last (Mins)', 'Sent tnx', 'Received Tnx',
#        'Number of Created Contracts', 'Unique Received From Addresses',
#        'Unique Sent To Addresses', 'min value received', 'max value received ',
#        'avg val received', 'min val sent', 'max val sent', 'avg val sent',
#        'min value sent to contract', 'max val sent to contract',
#        'avg value sent to contract',
#        'total transactions (including tnx to create contract',
#        'total Ether sent', 'total ether received',
#        'total ether sent contracts', 'total ether balance',
#        ' Total ERC20 tnxs', ' ERC20 total Ether received',
#        ' ERC20 total ether sent', ' ERC20 total Ether sent contract',
#        ' ERC20 uniq sent addr', ' ERC20 uniq rec addr',
#        ' ERC20 uniq sent addr.1', ' ERC20 uniq rec contract addr',
# ...

# %% [markdown]
# Check each columns data type: most columns has integer or float type except a few are object type

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4920 entries, 0 to 4919
# Data columns (total 51 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Unnamed: 0                                            4920 non-null   int64
#  1   Index                                                 4920 non-null   int64
#  2   Address                                               4920 non-null   object
#  3   FLAG                                                  4920 non-null   int64
#  4   Avg min between sent tnx                              4920 non-null   float64
#  5   Avg min between received tnx                          4920 non-null   float64
#  6   Time Diff between first and last (Mins)               4920 non-null   float64
#  7   Sent tnx                                              4920 non-null   int64
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4921 entries, 0 to 4920
# Data columns (total 50 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Unnamed: 0                                            4921 non-null   int64
#  1   Index                                                 4921 non-null   int64
#  2   Address                                               4921 non-null   object
#  3   Avg min between sent tnx                              4921 non-null   float64
#  4   Avg min between received tnx                          4921 non-null   float64
#  5   Time Diff between first and last (Mins)               4921 non-null   float64
#  6   Sent tnx                                              4921 non-null   int64
#  7   Received Tnx                                          4921 non-null   int64
# ...

# %% [markdown]
# Take a closer look at the summary of statistics pertaining the training DataFrame's columns

# %%
train_data.describe()
# Out:
#         Unnamed: 0        Index         FLAG  Avg min between sent tnx  \
# count  4920.000000  4920.000000  4920.000000               4920.000000
# mean   4982.883740  1838.606301     0.225407               5015.392793
# std    2825.307639  1235.890843     0.417892              22194.973117
# min       1.000000     2.000000     0.000000                  0.000000
# 25%    2546.750000   823.000000     0.000000                  0.000000
# 50%    5024.500000  1661.500000     0.000000                 16.745000
# 75%    7433.250000  2642.250000     0.000000                523.120000
# max    9838.000000  4728.000000     1.000000             430287.670000
#
#        Avg min between received tnx  Time Diff between first and last (Mins)  \
# count                   4920.000000                             4.920000e+03
# mean                    7852.953124                             2.177702e+05
# std                    22056.425873                             3.224689e+05
# ...

# %%
test_data.describe()
# Out:
#         Unnamed: 0        Index  Avg min between sent tnx  \
# count  4921.000000  4921.000000               4921.000000
# mean   4857.129039  1791.498273               5158.350122
# std    2855.498483  1208.876693              20756.125213
# min       0.000000     1.000000                  0.000000
# 25%    2354.000000   814.000000                  0.000000
# 50%    4828.000000  1612.000000                 17.800000
# 75%    7313.000000  2554.000000                651.520000
# max    9840.000000  4729.000000             377913.420000
#
#        Avg min between received tnx  Time Diff between first and last (Mins)  \
# count                   4921.000000                             4.921000e+03
# mean                    8156.718376                             2.188962e+05
# std                    24064.453701                             3.234379e+05
# min                        0.000000                             0.000000e+00
# ...

# %% [markdown]
# Since Fkag is the Target variable, here to check the distribution of its value and try to identify if patterns or anomalies, and whether or not this is imbalanced problem.

# %%
sns.countplot(x='FLAG',data=train_data)
# Out:
# <Axes: xlabel='FLAG', ylabel='count'>

# %% [markdown]
# Double check to see if any missing values in any columns or N/A

# %%
train_data.isna().sum()
# Out:
# Unnamed: 0                                                0
# Index                                                     0
# Address                                                   0
# FLAG                                                      0
# Avg min between sent tnx                                  0
# Avg min between received tnx                              0
# Time Diff between first and last (Mins)                   0
# Sent tnx                                                  0
# Received Tnx                                              0
# Number of Created Contracts                               0
# Unique Received From Addresses                            0
# Unique Sent To Addresses                                  0
# min value received                                        0
# max value received                                        0
# avg val received                                          0
# min val sent                                              0
# ...

# %%
test_data.isna().sum()
# Out:
# Unnamed: 0                                                0
# Index                                                     0
# Address                                                   0
# Avg min between sent tnx                                  0
# Avg min between received tnx                              0
# Time Diff between first and last (Mins)                   0
# Sent tnx                                                  0
# Received Tnx                                              0
# Number of Created Contracts                               0
# Unique Received From Addresses                            0
# Unique Sent To Addresses                                  0
# min value received                                        0
# max value received                                        0
# avg val received                                          0
# min val sent                                              0
# max val sent                                              0
# ...

# %% [markdown]
# Double check to see if any missing or NULL values in any columns

# %%
# Check for missing values
train_data.isnull().sum()
# Out:
# Unnamed: 0                                                0
# Index                                                     0
# Address                                                   0
# FLAG                                                      0
# Avg min between sent tnx                                  0
# Avg min between received tnx                              0
# Time Diff between first and last (Mins)                   0
# Sent tnx                                                  0
# Received Tnx                                              0
# Number of Created Contracts                               0
# Unique Received From Addresses                            0
# Unique Sent To Addresses                                  0
# min value received                                        0
# max value received                                        0
# avg val received                                          0
# min val sent                                              0
# ...

# %%
# Check for missing values
test_data.isnull().sum()
# Out:
# Unnamed: 0                                                0
# Index                                                     0
# Address                                                   0
# Avg min between sent tnx                                  0
# Avg min between received tnx                              0
# Time Diff between first and last (Mins)                   0
# Sent tnx                                                  0
# Received Tnx                                              0
# Number of Created Contracts                               0
# Unique Received From Addresses                            0
# Unique Sent To Addresses                                  0
# min value received                                        0
# max value received                                        0
# avg val received                                          0
# min val sent                                              0
# max val sent                                              0
# ...

# %% [markdown]
# Plot the heat map to show # of N/A or missing values in the data set

# %%
sns.heatmap(train_data.isna())
# Out:
# <Axes: >

# %%
sns.heatmap(test_data.isna())
# Out:
# <Axes: >

# %%
train_data=pd.read_csv('train_dataset.csv').drop(columns=['Unnamed: 0'])
test_data=pd.read_csv('test_dataset.csv').drop(columns=['Unnamed: 0'])

# %%
train_data.columns
# Out:
# Index(['Index', 'Address', 'FLAG', 'Avg min between sent tnx',
#        'Avg min between received tnx',
#        'Time Diff between first and last (Mins)', 'Sent tnx', 'Received Tnx',
#        'Number of Created Contracts', 'Unique Received From Addresses',
#        'Unique Sent To Addresses', 'min value received', 'max value received ',
#        'avg val received', 'min val sent', 'max val sent', 'avg val sent',
#        'min value sent to contract', 'max val sent to contract',
#        'avg value sent to contract',
#        'total transactions (including tnx to create contract',
#        'total Ether sent', 'total ether received',
#        'total ether sent contracts', 'total ether balance',
#        ' Total ERC20 tnxs', ' ERC20 total Ether received',
#        ' ERC20 total ether sent', ' ERC20 total Ether sent contract',
#        ' ERC20 uniq sent addr', ' ERC20 uniq rec addr',
#        ' ERC20 uniq sent addr.1', ' ERC20 uniq rec contract addr',
# ...

# %%
.drop(columns=['Index']).drop_duplicates().shape[0]train_data
# Out:
# 4916

# %%
# Check for NaN values and the data type of the columns that contain them
nan_columns = train_data.isna().sum()
nan_columns = nan_columns[nan_columns > 0]
nan_columns_dtypes = train_data[nan_columns.index].dtypes


# Replace NaN values in numerical columns with the median
numerical_columns = nan_columns_dtypes[nan_columns_dtypes == 'float64'].index
for col in numerical_columns:
    median_value = train_data[col].median()
    train_data[col].fillna(median_value, inplace=True)

# Replace NaN values in categorical columns with 'Unknown'
categorical_columns = nan_columns_dtypes[nan_columns_dtypes == 'object'].index
for col in categorical_columns:
    train_data[col].fillna('Unknown', inplace=True)

# Verify that there are no more NaN values
train_data.isna().sum().max()  # This should now be 0
# Out:
# 0

# %%
from sklearn.preprocessing import StandardScaler

# Normalize the features
# scaler = StandardScaler()
categorical_columns = ['Address', ' ERC20 most sent token type', ' ERC20_most_rec_token_type']

# Applying one-hot encoding
data_encoded = pd.get_dummies(train_data, columns=categorical_columns)
# Drop the ID column, since it is irrelvant
X=data_encoded.drop(['FLAG'], axis=1)
# X_normalized = scaler.fit_transform(X)

y=data_encoded['FLAG']

X.head()
# Out:
#    Index  Avg min between sent tnx  Avg min between received tnx  \
# 0   2139                      0.00                        419.62
# 1   3967                      0.00                          0.00
# 2    797                      0.00                          0.00
# 3   1174                   2848.66                       7022.17
# 4   1194                      0.00                       1126.64
#
#    Time Diff between first and last (Mins)  Sent tnx  Received Tnx  \
# 0                                323529.40         0           771
# 1                                    66.22         1             1
# 2                                     0.00         0             0
# 3                               1035306.22         6           145
# 4                                159982.33         0           142
#
#    Number of Created Contracts  Unique Received From Addresses  \
# 0                            1                             124
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, roc_auc_score
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
# !pip install catboost
from catboost import CatBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier


# Initialize models
models = {
    "Logistic Regression": LogisticRegression(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "XGBoosting": XGBClassifier(objective='binary:logistic'),
    # "LGBMClassifier": LGBMClassifier(verbose = -1),
    "CatBoost": CatBoostClassifier(verbose=False),
    "Bagging Classifier": BaggingClassifier(random_state=42),
    "Ada Boost Classifier": AdaBoostClassifier(random_state=42),
    "KNeighbor Classifier": KNeighborsClassifier()

}

# Train models and store performance metrics
model_performance = {}

# Iterate over each model, train it, make predictions and calculate performance metrics
for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    y_prob = model.predict_proba(x_test)[:, 1]
    accuracy = accuracy_score(y_test, y_pred)
    roc_auc = roc_auc_score(y_test, y_prob)
    model_performance[name] = {"Accuracy": accuracy, "ROC AUC": roc_auc}

# Print out the stored performance metrics for each model
for model, performance in model_performance.items():
    print(f"{model}:")
    for metric, value in performance.items():
        print(f"  {metric}: {value:.8f}")
    print()
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression:
#   Accuracy: 0.77947154
#   ROC AUC: 0.70800297
#
# Random Forest:
#   Accuracy: 0.98882114
#   ROC AUC: 0.99606858
#
# Gradient Boosting:
#   Accuracy: 0.99085366
#   ROC AUC: 0.99933528
#
# XGBoosting:
#   Accuracy: 0.99288618
#   ROC AUC: 0.99876638
#
# CatBoost:
#   Accuracy: 0.99288618
#   ROC AUC: 0.99958081
#
# Bagging Classifier:
#   Accuracy: 0.98983740
#   ROC AUC: 0.98983460
#
# Ada Boost Classifier:
#   Accuracy: 0.99085366
# ...

# %%
# All necessary imports

# General:
import pandas as pd
import numpy as np
import seaborn as sns

# Graphing:
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# Modeling:
from sklearn.linear_model import Ridge, Lasso, LogisticRegression, RidgeClassifier, SGDClassifier, Perceptron
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier, StackingClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score, train_test_split, RandomizedSearchCV, StratifiedKFold
from sklearn.svm import SVC
from sklearn.metrics import roc_curve, auc, roc_auc_score, accuracy_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OrdinalEncoder
import xgboost as xgb
# %pip install lightgbm --user
# The above install was giving me a bit of trouble, added '--user' after 'lightgbm' even though this is not the best idea
import lightgbm as lgb
from sklearn.tree import DecisionTreeClassifier
from sklearn.base import clone
from sklearn.neighbors import KNeighborsClassifier, NearestCentroid
# %pip install tensorflow --user
# The above install was giving me a bit of trouble, added '--user' after 'tensorflow' even though this is not the best idea
import tensorflow as tf
from sklearn.naive_bayes import GaussianNB
# %pip install catboost --user
# The above install was giving me a bit of trouble, added '--user' after 'catboost' even though this is not the best idea
import catboost
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.calibration import CalibratedClassifierCV
# %pip install keras-tuner --user
# The above install was giving me a bit of trouble, added '--user' after 'keras-tuner' even though this is not the best idea
import keras_tuner as kt
from tensorflow.keras.optimizers import Adam # Not sure why this throws an error on my end, it does import correctly even though it shows it could not be resolved
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 4.6 MB/s eta 0:00:00
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-95abdcb9e230> in <cell line: 33>()
#      31 get_ipython().run_line_magic('pip', 'install catboost --user')
#      32 # The above install was giving me a bit of trouble, added '--user' after 'catboost' even though this is not the best idea
# ---> 33 import catboost
#      34 from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
#      35 from sklearn.calibration import CalibratedClassifierCV
#
# ModuleNotFoundError: No module named 'catboost'

# %%
# Loading data
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

display(train_data.head())
display(test_data.head())

original = pd.read_csv("original.csv")
original['Attrition'] = original['Attrition'].map({'Yes': 1, 'No': 0})

# original.drop(columns=['EmployeeNumber'], inplace=True)
train_data.drop(columns=['id'], inplace=True)
original = original[list(train_data.columns)]

train_data = pd.concat([train_data, original]).reset_index(drop=True)

# Checking for nulls
missing_train = train_data.isnull().sum()
missing_test = test_data.isnull().sum()

missing_train = missing_train[missing_train > 0]
missing_test = missing_test[missing_test > 0]

print(missing_train.to_string())
print(missing_test.to_string())
# We find that there is no missing data for now.

# Loading vars
# X_train = train_data.drop(columns=['Attrition'])
# y_train = train_data['Attrition']
# X_test = test_data.drop(columns=['id'])

# print('X_train shape: ', X_train.shape)
# print('Y_train shape: ', y_train.shape)
# print('X_test shape: ', X_test.shape)
train_data.shape
# Out:
#    id  Age     BusinessTravel  DailyRate              Department  \
# 0   0   36  Travel_Frequently        599  Research & Development
# 1   1   35      Travel_Rarely        921                   Sales
# 2   2   32      Travel_Rarely        718                   Sales
# 3   3   38      Travel_Rarely       1488  Research & Development
# 4   4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  ... StandardHours  StockOptionLevel  \
# 0                        4  ...            80                 1
# 1                        1  ...            80                 1
# ...

# %%
# Drop columns with only 1 value


# Encode object columns with Ordinal Encoding
object_columns = train_data.select_dtypes(include=['object']).columns
ordinal_encoder = OrdinalEncoder()
train_data[object_columns] = ordinal_encoder.fit_transform(train_data[object_columns])
# train_data[object_columns] = ordinal_encoder.transform(train_data[object_columns])

# We use Ordinal instead of One Hot as One Hot creates binary columns for every single new feature and we already have a lot of features. Also, Ordinal keeps the logical order in certain categories that are ranked as less likely to likely which is the case for our dataset. Ordinal is better for this case.

# Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(train_data)

# DataFrames for visualization
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=train_data.columns)
X_train_scaled_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3147 entries, 0 to 3146
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       3147 non-null   float64
#  1   BusinessTravel            3147 non-null   float64
#  2   DailyRate                 3147 non-null   float64
#  3   Department                3147 non-null   float64
#  4   DistanceFromHome          3147 non-null   float64
#  5   Education                 3147 non-null   float64
#  6   EducationField            3147 non-null   float64
#  7   EmployeeCount             3147 non-null   float64
#  8   EnvironmentSatisfaction   3147 non-null   float64
#  9   Gender                    3147 non-null   float64
#  10  HourlyRate                3147 non-null   float64
#  11  JobInvolvement            3147 non-null   float64
#  12  JobLevel                  3147 non-null   float64
# ...

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif

# Making a copy of the train_data to work with it without altering the original dataset
df_copy = X_train_scaled_df.copy()

# Dropping the 'Y' column from the copy of the dataset as we don't need it in the features set
df_copy = X_train_scaled_df.drop(['Attrition'], axis=1)

# Assigning the remaining columns as features
features = df_copy.loc[:,df_copy.columns]

# Assigning the 'Y' column from the original data as the target variable
target = X_train_scaled_df['Attrition']

# Setting up SelectKBest with the ANOVA F-test as the score function to evaluate all features
best_features = SelectKBest(score_func=f_classif, k='all')

# Fitting SelectKBest to the features and target
fit = best_features.fit(features, target)

# Creating a DataFrame with the scores for each feature
featureScores = pd.DataFrame(data=fit.scores_, index=features.columns, columns=['ANOVA Score'])

# Setting up the matplotlib figure with a defined size
plt.subplots(figsize=(5, 7))

# Defining the color map for the heatmap
colors = 'coolwarm' # Assuming 'coolwarm' is intended, which is a valid matplotlib colormap

# Creating the heatmap with the feature scores, sorted by the ANOVA score in descending order
sns.heatmap(featureScores.sort_values(by='ANOVA Score', ascending=False),
            annot=True, cmap=colors, linewidths=0.4, linecolor='black', fmt='.2f')

# Adding a title to the heatmap
plt.title('Selection of Numerical Features')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_selection/_univariate_selection.py:112: UserWarning: Features [ 7 19 24] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_selection/_univariate_selection.py:113: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw
